# %% [markdown]
# ## Jupyter Lab Tutorial

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({'num_legs': [2, 4], 'num_wings': [2, 0]}, index=['falcon', 'dog'])
print(df)
pd.__version__
# Out:
#         num_legs  num_wings
# falcon         2          2
# dog            4          0
# '1.4.3'

# %%
df.columns
# Out:
# Index(['num_legs', 'num_wings'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, falcon to dog
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   num_legs   2 non-null      int64
#  1   num_wings  2 non-null      int64
# dtypes: int64(2)
# memory usage: 48.0+ bytes

# %%
import math 
math.pi
# Out:
# 3.141592653589793

# %%
import population 

for country in population.data.order_countries(2050)[:5]:
  population.data.plot_country(country)

# plt.legend()
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (10, 5)
plt.xlabel("Year")
plt.ylabel("Population [Millions]")
plt.title("UN Population Projections")
plt.savefig('test2png.png', dpi=100)
plt.show()

# %%
for style in plt.style.available:
    print(style)
# Out:
# Solarize_Light2
# _classic_test_patch
# _mpl-gallery
# _mpl-gallery-nogrid
# bmh
# classic
# dark_background
# fast
# fivethirtyeight
# ggplot
# grayscale
# seaborn
# seaborn-bright
# seaborn-colorblind
# seaborn-dark
# seaborn-dark-palette
# seaborn-darkgrid
# seaborn-deep
# seaborn-muted
# seaborn-notebook
# seaborn-paper
# seaborn-pastel
# seaborn-poster
# seaborn-talk
# seaborn-ticks
# seaborn-white
# seaborn-whitegrid
# tableau-colorblind10

# %%
print('hello world')
# Out:
# hello world
